# %%
# !pip install mysql-connector-python
# !pip install pymysql

# %%
import mysql.connector
import pandas as pd

# Configurer la connexion
conn = mysql.connector.connect(
    host="localhost",       # ou l'IP du serveur MySQL
    user="root",
    password="343877BMM07m+",
    database="db_stage_bcc"
)

# Vérifier la connexion
if conn.is_connected():
    print("Connexion réussie à MySQL !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import mysql.connector
#       2 import pandas as pd
#       4 # Configurer la connexion
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import pymysql
import pandas as pd

try:
    conn = pymysql.connect(
        host="localhost",
        user="testuser",
        password="motdepasse123",
        database="db_stage_bcc"
    )
    print("Connexion réussie ✅")

except Exception as e:
    print("Erreur de connexion :", e)
# Out:
# Connexion réussie ✅

# %%
# Requête SQL
query = "SELECT * FROM user;"
df = pd.read_sql(query, conn)

# Afficher le DataFrame
print(df.head())

# Fermer la connexion
conn.close()
# Out:
#    id_user  nom_user postnom_user prenom_user sexe_user  phone_user  \
# 0       33   Bonsomi      Manassé     Manassé         M  0825568355
# 1       34   Bonsomi     Nyandimo        Ruth         F        None
# 2       35   Bonsomi         Moto       Sarah         F        None
# 3       36   Mapamba  Warrabs'aba   Christian         M        None
# 4       37  Bongenda      Bonsomi      Esther         F        None
#
#                       mail_user  \
# 0  manassebonsomi.bmm@gmail.com
# 1         ruthbonsomi@gmail.com
# 2        sarahbonsomi@gmail.com
# 3    christianmapamba@gmail.com
# 4      estherbongenda@gmail.com
#
#                                             mdp_user    date_inscription  \
# 0  $2y$10$/iY1qbqmrOdX9zL3cpBxHutzb7y/qQF9IVTJCut... 2024-05-04 16:21:54
# 1  $2y$10$/iY1qbqmrOdX9zL3cpBxHutzb7y/qQF9IVTJCut... 2024-05-27 18:15:06
# 2  $2y$10$/iY1qbqmrOdX9zL3cpBxHutzb7y/qQF9IVTJCut... 2024-05-29 16:33:42
# ...

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine
import pandas as pd

# Création de l'engine
engine = create_engine("mysql+pymysql://testuser:motdepasse123@localhost/db_stage_bcc")

# Requête SQL
query = "SELECT * FROM stage;"

# Charger dans un DataFrame
df = pd.read_sql(query, engine)

print(df.head())
# Out:
#    id_stage                                              sujet  fin_stage  \
# 0         1  Détection des objets par intelligence artifici...          1
# 1         3                                                ...          0
# 2         5   Détection des objets pour la régulation routière          0
#
#    id_stagiaire  id_affectation  id_service
# 0            33               1           4
# 1            36               4           4
# 2            33               1           4

# %%
# Statistiques descriptives
print(df.describe())

# Nombre de produits par catégorie
print(df['sujet'].value_counts())
# Out:
#        id_stage  fin_stage  id_stagiaire  id_affectation  id_service
# count       3.0   3.000000      3.000000        3.000000         3.0
# mean        3.0   0.333333     34.000000        2.000000         4.0
# std         2.0   0.577350      1.732051        1.732051         0.0
# min         1.0   0.000000     33.000000        1.000000         4.0
# 25%         2.0   0.000000     33.000000        1.000000         4.0
# 50%         3.0   0.000000     33.000000        1.000000         4.0
# 75%         4.0   0.500000     34.500000        2.500000         4.0
# max         5.0   1.000000     36.000000        4.000000         4.0
# sujet
# Détection des objets par intelligence artificielle.    1
# ...                                                    1
# Détection des objets pour la régulation routière       1
# Name: count, dtype: int64
